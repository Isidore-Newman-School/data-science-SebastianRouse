# %% [markdown]
# # Data_1.4 Plotting

# %% [markdown]
# Importing pandas, numpy, and matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

df = pd.read_csv('file.csv')
df.set_index('name', inplace = True)

plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %% [markdown]
# Change the style of the graph

# %%
plt.style.use('seaborn-colorblind')

# %% [markdown]
# Ploting the Data frame as a scatter plot

# %%
df.plot('fat', 'calories', kind = 'scatter')

# %% [markdown]
# Plotting fat histogram

# %%
df.hist(column = 'fat')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A3A45CB080>]],
#       dtype=object)

# %% [markdown]
# Plotting bar graph

# %%
df.head().plot('fat', 'calories', kind = 'bar', title = 'bar graph of fat against calories')
ax = df.head().plot('fat', 'calories', kind = 'bar', title = 'bar graph of fat against calories')
ax.set_xlabel("fat")
ax.set_ylabel("calories")
# Out:
# Text(0,0.5,'calories')

# %% [markdown]
# Plotting fat against calories

# %%
df.plot.kde(x = 'sugars', y = 'fat')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-3ba5338a7deb> in <module>()
#       1 df.plot.kde(x = 'sugars', y = 'fat')
# ----> 2 df.rename_axis(mapper, axis=0, copy=True, inplace=False)
#
# NameError: name 'mapper' is not defined
